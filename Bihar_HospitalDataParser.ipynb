# %% [markdown]
# <a href="https://colab.research.google.com/github/ApoorvGuptaAi/iitk-india-covid-data-parser/blob/main/Bihar_HospitalDataParser.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from bs4 import BeautifulSoup
from datetime import datetime
from dataclasses import dataclass
from typing import List
import dateutil
import requests

# %%
@dataclass
class Resource:
  resource_type: str    # Resource type defined at https://github.com/abhinavj13/iitk-covid-help-api/blob/master/src/services/dataLead/db/enum.ts   
  resource_description: str
  resource_total: int
  resource_available: int

@dataclass
class Hospital:
  name: str
  address: str
  district: str
  city: str
  state: str
  location: str
  last_updated: datetime
  resources: List[Resource]

# %%
def get_bihar_soup():
  covid_bihar_home_url = 'https://covid19health.bihar.gov.in/DailyDashboard/BedsOccupied'
  bihar_home_response = requests.get(covid_bihar_home_url)
  return BeautifulSoup(bihar_home_response.text, 'html.parser')

bihar_soup = get_bihar_soup()

# %%
def get_updated_timestamp(updated_text):
  if updated_text:
    return dateutil.parser.parse(updated_text)

# %%
def parse_hospital_data(hospital_tds):
  parsed_data = {
      'district': hospital_tds[0].find('span', {'class': 'bed-district'}).text,
      'name': hospital_tds[1].find('span', {'class': 'bed-title'}).text,
      'map_href': hospital_tds[1].find('a')['href'],
      'category': hospital_tds[2].text,
      'last_updated': get_updated_timestamp(hospital_tds[3].text),
      'total_beds': hospital_tds[4].text,
      'vacant_beds': hospital_tds[5].text,
      'icu_beds': hospital_tds[6].text,
      'vacant_icu_beds': hospital_tds[7].text,
      'contact_phone': hospital_tds[8].text,
  }
  return parsed_data

def get_bihar_data(bihar_soup):
  master_table = bihar_soup.find('table', {'id': 'example'})
  hospital_rows = master_table.find_all('tr')
  all_hospitals = []
  for hospital_row in hospital_rows[1:]:
    hospital_tds = hospital_row.find_all('td')
    hospital_data = parse_hospital_data(hospital_tds)
    hospital = Hospital('', '', '', '', '', '', datetime.now, None)
    all_hospitals.append(hospital)
    hospital.name = hospital_data['name']
    hospital.district = hospital_data['district']
    hospital.state = 'BIHAR'
    hospital.location = hospital_data['map_href']
    hospital.last_updated = hospital_data['last_updated']
    hospital.resources = [
      Resource(
          resource_type='TOTAL_BEDS',
          resource_description='hospital beds',
          resource_total=hospital_data['total_beds'],
          resource_available=hospital_data['vacant_beds']),
      Resource(
          resource_type='ICU_WITHOUT_VENTILATOR',
          resource_description='icu beds',
          resource_total=hospital_data['icu_beds'],
          resource_available=hospital_data['vacant_icu_beds']),                
    ]
    print(hospital)
  return all_hospitals

all_hospitals = get_bihar_data(bihar_soup)
# Out:
# Hospital(name='DH Nawada', address='', district='NAWADA', city='', state='BIHAR', location='/DailyDashboard/Map?lat=24.88726&lon=85.54591&title=DH Nawada,&dis=NAWADA', last_updated=datetime.datetime(2021, 5, 2, 19, 4), resources=[Resource(resource_type='TOTAL_BEDS', resource_description='hospital beds', resource_total='60', resource_available='39'), Resource(resource_type='ICU_WITHOUT_VENTILATOR', resource_description='icu beds', resource_total='10', resource_available='10')])
# Hospital(name='Sub Divisional Hospital Forbesganj, Araria', address='', district='ARARIA', city='', state='BIHAR', location='/DailyDashboard/Map?lat=26.30229&lon=87.25456&title=Sub Divisional Hospital Forbesganj, Araria,&dis=ARARIA', last_updated=datetime.datetime(2021, 4, 26, 8, 55), resources=[Resource(resource_type='TOTAL_BEDS', resource_description='hospital beds', resource_total='75', resource_available='75'), Resource(resource_type='ICU_WITHOUT_VENTILATOR', resource_description='icu beds', resource_total='0', resource_available='0')])
# Hospital(name='SDH Rajauli', address='', district='NAWADA', city='', state='BIHAR', location='/DailyDashboard/Map?lat=24.64426&lon=85.49525&title=SDH Rajauli,&dis=NAWADA', last_updated=datetime.datetime(2021, 5, 2, 19, 5), resources=[Resource(resource_type='TOTAL_BEDS', resource_description='hospital beds', resource_total='75', resource_available='74'), Resource(resource_type='ICU_WITHOUT_VENTILATOR', resource_description='icu beds', resource_total='0', resource_available='0')])
# Hospital(name='Sadar Hospital Araria', address='', district='ARARIA', city='', state='BIHAR', location='/DailyDashboard/Map?lat=26.13002&lon=87.46879&title=Sadar Hospital Araria,&dis=ARARIA', last_updated=datetime.datetime(2021, 4, 26, 8, 52), resources=[Resource(resource_type='TOTAL_BEDS', resource_description='hospital beds', resource_total='10', resource_available='10'), Resource(resource_type='ICU_WITHOUT_VENTILATOR', resource_description='icu beds', resource_total='0', resource_available='0')])
# Hospital(name='HOSTEL BLOCK, ANM SCHOOLGIRLS HOSTEL SADAR HOSPITAL ARWAL', address='', district='ARWAL', city='', state='BIHAR', location='/DailyDashboard/Map?lat=25.23293&lon=84.67801&title=HOSTEL BLOCK, ANM SCHOOLGIRLS HOSTEL SADAR HOSPITAL ARWAL,&dis=ARWAL', last_updated=datetime.datetime(2021, 5, 2, 11, 17), resources=[Resource(resource_type='TOTAL_BEDS', resource_description='hospital beds', resource_total='156', resource_available='152'), Resource(resource_type='ICU_WITHOUT_VENTILATOR', resource_description='icu beds', resource_total='0', resource_available='0')])
# Hospital(name='DIET Tarar, Daudnagar', address='', district='AURANGABAD', city='', state='BIHAR', location='/DailyDashboard/Map?lat=24.7703&lon=84.35374&title=DIET Tarar, Daudnagar,&dis=AURANGABAD', last_updated=datetime.datetime(2021, 5, 1, 14, 48), resources=[Resource(resource_type='TOTAL_BEDS', resource_description='hospital beds', resource_total='50', resource_available='47'), Resource(resource_type='ICU_WITHOUT_VENTILATOR', resource_description='icu beds', resource_total='0', resource_available='0')])
# Hospital(name='SDH Daudnagar', address='', district='AURANGABAD', city='', state='BIHAR', location='/DailyDashboard/Map?lat=25.0391&lon=84.41473&title=SDH Daudnagar,&dis=AURANGABAD', last_updated=datetime.datetime(2021, 5, 1, 15, 11), resources=[Resource(resource_type='TOTAL_BEDS', resource_description='hospital beds', resource_total='75', resource_available='75'), Resource(resource_type='ICU_WITHOUT_VENTILATOR', resource_description='icu beds', resource_total='0', resource_available='0')])
# Hospital(name='SDH Masaurhi', address='', district='PATNA', city='', state='BIHAR', location='/DailyDashboard/Map?lat=25.36794&lon=85.04321&title=SDH Masaurhi,&dis=PATNA', last_updated=datetime.datetime(2021, 5, 2, 18, 34), resources=[Resource(resource_type='TOTAL_BEDS', resource_description='hospital beds', resource_total='25', resource_available='18'), Resource(resource_type='ICU_WITHOUT_VENTILATOR', resource_description='icu beds', resource_total='0', resource_available='0')])
# Hospital(name='DH Banka', address='', district='BANKA', city='', state='BIHAR', location='/DailyDashboard/Map?lat=24.86114&lon=86.9116&title=DH Banka,&dis=BANKA', last_updated=datetime.datetime(2021, 5, 2, 16, 46), resources=[Resource(resource_type='TOTAL_BEDS', resource_description='hospital beds', resource_total='100', resource_available='80'), Resource(resource_type='ICU_WITHOUT_VENTILATOR', resource_description='icu beds', resource_total='0', resource_available='0')])
# Hospital(name='Sadar Hospital,  Purnea', address='', district='PURNIA', city='', state='BIHAR', location='/DailyDashboard/Map?lat=25.78498&lon=87.48845&title=Sadar Hospital,  Purnea,&dis=PURNIA', last_updated=datetime.datetime(2021, 5, 2, 19, 37), resources=[Resource(resource_type='TOTAL_BEDS', resource_description='hospital beds', resource_total='100', resource_available='60'), Resource(resource_type='ICU_WITHOUT_VENTILATOR', resource_description='icu beds', resource_total='0', resource_available='0')])
# Hospital(name='DH Begusarai', address='', district='BEGUSARAI', city='', state='BIHAR', location='/DailyDashboard/Map?lat=25.4142&lon=86.13595&title=DH Begusarai,&dis=BEGUSARAI', last_updated=datetime.datetime(2021, 5, 2, 21, 35), resources=[Resource(resource_type='TOTAL_BEDS', resource_description='hospital beds', resource_total='50', resource_available='18'), Resource(resource_type='ICU_WITHOUT_VENTILATOR', resource_description='icu beds', resource_total='9', resource_available='9')])
# Hospital(name='Sub Divisional Hospital Dhamdaha.', address='', district='PURNIA', city='', state='BIHAR', location='/DailyDashboard/Map?lat=25.72961&lon=87.18222&title=Sub Divisional Hospital Dhamdaha.,&dis=PURNIA', last_updated=datetime.datetime(2021, 5, 2, 19, 39), resources=[Resource(resource_type='TOTAL_BEDS', resource_description='hospital beds', resource_total='55', resource_available='49'), Resource(resource_type='ICU_WITHOUT_VENTILATOR', resource_description='icu beds', resource_total='0', resource_available='0')])
# Hospital(name='SDH Baliya', address='', district='BEGUSARAI', city='', state='BIHAR', location='/DailyDashboard/Map?lat=25.42312&lon=86.30812&title=SDH Baliya,&dis=BEGUSARAI', last_updated=datetime.datetime(2021, 5, 2, 13, 33), resources=[Resource(resource_type='TOTAL_BEDS', resource_description='hospital beds', resource_total='100', resource_available='85'), Resource(resource_type='ICU_WITHOUT_VENTILATOR', resource_description='icu beds', resource_total='0', resource_available='0')])
# Hospital(name='Sub Divisional Hospital Banmankhi.', address='', district='PURNIA', city='', state='BIHAR', location='/DailyDashboard/Map?lat=25.88404&lon=87.18878&title=Sub Divisional Hospital Banmankhi.,&dis=PURNIA', last_updated=datetime.datetime(2021, 5, 2, 19, 38), resources=[Resource(resource_type='TOTAL_BEDS', resource_description='hospital beds', resource_total='70', resource_available='48'), Resource(resource_type='ICU_WITHOUT_VENTILATOR', resource_description='icu beds', resource_total='0', resource_available='0')])
# Hospital(name='Sadar Hospital Sasaram  (Para Medical Boys Hostel)', address='', district='ROHTAS', city='', state='BIHAR', location='/DailyDashboard/Map?lat=24.95475&lon=84.017&title=Sadar Hospital Sasaram  (Para Medical Boys Hostel),&dis=ROHTAS', last_updated=datetime.datetime(2021, 5, 1, 11, 22), resources=[Resource(resource_type='TOTAL_BEDS', resource_description='hospital beds', resource_total='84', resource_available='79'), Resource(resource_type='ICU_WITHOUT_VENTILATOR', resource_description='icu beds', resource_total='0', resource_available='0')])
# Hospital(name='SDH Dehri', address='', district='ROHTAS', city='', state='BIHAR', location='/DailyDashboard/Map?lat=24.89593&lon=84.18354&title=SDH Dehri,&dis=ROHTAS', last_updated=datetime.datetime(2021, 5, 1, 11, 23), resources=[Resource(resource_type='TOTAL_BEDS', resource_description='hospital beds', resource_total='50', resource_available='35'), Resource(resource_type='ICU_WITHOUT_VENTILATOR', resource_description='icu beds', resource_total='0', resource_available='0')])
# Hospital(name='SDH Naugachiya', address='', district='BHAGALPUR', city='', state='BIHAR', location='/DailyDashboard/Map?lat=25.3881&lon=87.0991&title=SDH Naugachiya,&dis=BHAGALPUR', last_updated=datetime.datetime(2021, 5, 2, 18, 18), resources=[Resource(resource_type='TOTAL_BEDS', resource_description='hospital beds', resource_total='35', resource_available='35'), Resource(resource_type='ICU_WITHOUT_VENTILATOR', resource_description='icu beds', resource_total='0', resource_available='0')])
# Hospital(name='paramedical collage', address='', district='SAHARSA', city='', state='BIHAR', location='/DailyDashboard/Map?lat=25.5317&lon=86.3525&title=paramedical collage,&dis=SAHARSA', last_updated=None, resources=[Resource(resource_type='TOTAL_BEDS', resource_description='hospital beds', resource_total='100', resource_available='100'), Resource(resource_type='ICU_WITHOUT_VENTILATOR', resource_description='icu beds', resource_total='0', resource_available='0')])
# Hospital(name='District Hospital Ara', address='', district='BHOJPUR', city='', state='BIHAR', location='/DailyDashboard/Map?lat=25.55867&lon=84.67094&title=District Hospital Ara,&dis=BHOJPUR', last_updated=datetime.datetime(2021, 5, 2, 16, 23), resources=[Resource(resource_type='TOTAL_BEDS', resource_description='hospital beds', resource_total='50', resource_available='29'), Resource(resource_type='ICU_WITHOUT_VENTILATOR', resource_description='icu beds', resource_total='3', resource_available='3')])
# Hospital(name='SDH Jagdishpur', address='', district='BHOJPUR', city='', state='BIHAR', location='/DailyDashboard/Map?lat=25.47938&lon=84.4386&title=SDH Jagdishpur,&dis=BHOJPUR', last_updated=datetime.datetime(2021, 5, 2, 17, 30), resources=[Resource(resource_type='TOTAL_BEDS', resource_description='hospital beds', resource_total='50', resource_available='2'), Resource(resource_type='ICU_WITHOUT_VENTILATOR', resource_description='icu beds', resource_total='0', resource_available='0')])
# Hospital(name='ANM Training School Hostel SDH Rosera', address='', district='SAMASTIPUR', city='', state='BIHAR', location='/DailyDashboard/Map?lat=25.74958&lon=86.03795&title=ANM Training School Hostel SDH Rosera,&dis=SAMASTIPUR', last_updated=datetime.datetime(2021, 5, 2, 17, 45), resources=[Resource(resource_type='TOTAL_BEDS', resource_description='hospital beds', resource_total='60', resource_available='48'), Resource(resource_type='ICU_WITHOUT_VENTILATOR', resource_description='icu beds', resource_total='0', resource_available='0')])
# Hospital(name='DIET CENTER II & GNM Para Medical Hostel', address='', district='EAST CHAMPARAN', city='', state='BIHAR', location='/DailyDashboard/Map?lat=0&lon=0&title=DIET CENTER II & GNM Para Medical Hostel,&dis=EAST CHAMPARAN', last_updated=datetime.datetime(2021, 4, 27, 17, 48), resources=[Resource(resource_type='TOTAL_BEDS', resource_description='hospital beds', resource_total='335', resource_available='321'), Resource(resource_type='ICU_WITHOUT_VENTILATOR', resource_description='icu beds', resource_total='4', resource_available='4')])
# Hospital(name='SDH Building Pakaridayal', address='', district='EAST CHAMPARAN', city='', state='BIHAR', location='/DailyDashboard/Map?lat=26.54622&lon=85.06529&title=SDH Building Pakaridayal,&dis=EAST CHAMPARAN', last_updated=None, resources=[Resource(resource_type='TOTAL_BEDS', resource_description='hospital beds', resource_total='50', resource_available='50'), Resource(resource_type='ICU_WITHOUT_VENTILATOR', resource_description='icu beds', resource_total='0', resource_available='0')])
# Hospital(name='ANM Training School, Rosera', address='', district='SAMASTIPUR', city='', state='BIHAR', location='/DailyDashboard/Map?lat=25.74958&lon=86.03795&title=ANM Training School, Rosera,&dis=SAMASTIPUR', last_updated=None, resources=[Resource(resource_type='TOTAL_BEDS', resource_description='hospital beds', resource_total='50', resource_available='50'), Resource(resource_type='ICU_WITHOUT_VENTILATOR', resource_description='icu beds', resource_total='0', resource_available='0')])
# Hospital(name='ANM Training School,Dalsinghsarai', address='', district='SAMASTIPUR', city='', state='BIHAR', location='/DailyDashboard/Map?lat=25.6675&lon=85.83759&title=ANM Training School,Dalsinghsarai,&dis=SAMASTIPUR', last_updated=datetime.datetime(2021, 5, 2, 17, 46), resources=[Resource(resource_type='TOTAL_BEDS', resource_description='hospital beds', resource_total='50', resource_available='20'), Resource(resource_type='ICU_WITHOUT_VENTILATOR', resource_description='icu beds', resource_total='0', resource_available='0')])
# Hospital(name='ANM Hostel, Sikrahna (RH Dhaka Campus)', address='', district='EAST CHAMPARAN', city='', state='BIHAR', location='/DailyDashboard/Map?lat=0&lon=0&title=ANM Hostel, Sikrahna (RH Dhaka Campus),&dis=EAST CHAMPARAN', last_updated=datetime.datetime(2021, 4, 26, 12, 50), resources=[Resource(resource_type='TOTAL_BEDS', resource_description='hospital beds', resource_total='50', resource_available='49'), Resource(resource_type='ICU_WITHOUT_VENTILATOR', resource_description='icu beds', resource_total='0', resource_available='0')])
# Hospital(name='ANM Hostel, SDH Areraj', address='', district='EAST CHAMPARAN', city='', state='BIHAR', location='/DailyDashboard/Map?lat=26.5476&lon=84.67188&title=ANM Hostel, SDH Areraj,&dis=EAST CHAMPARAN', last_updated=None, resources=[Resource(resource_type='TOTAL_BEDS', resource_description='hospital beds', resource_total='50', resource_available='50'), Resource(resource_type='ICU_WITHOUT_VENTILATOR', resource_description='icu beds', resource_total='0', resource_available='0')])
# Hospital(name='ANM Hostel, SDH Chakiya', address='', district='EAST CHAMPARAN', city='', state='BIHAR', location='/DailyDashboard/Map?lat=26.41367&lon=85.05087&title=ANM Hostel, SDH Chakiya,&dis=EAST CHAMPARAN', last_updated=None, resources=[Resource(resource_type='TOTAL_BEDS', resource_description='hospital beds', resource_total='50', resource_available='50'), Resource(resource_type='ICU_WITHOUT_VENTILATOR', resource_description='icu beds', resource_total='0', resource_available='0')])
# Hospital(name='SDH Pusa', address='', district='SAMASTIPUR', city='', state='BIHAR', location='/DailyDashboard/Map?lat=25.98192&lon=85.66663&title=SDH Pusa,&dis=SAMASTIPUR', last_updated=None, resources=[Resource(resource_type='TOTAL_BEDS', resource_description='hospital beds', resource_total='30', resource_available='30'), Resource(resource_type='ICU_WITHOUT_VENTILATOR', resource_description='icu beds', resource_total='0', resource_available='0')])
# Hospital(name='ANM Training School, Jagdishpur', address='', district='BHOJPUR', city='', state='BIHAR', location='/DailyDashboard/Map?lat=25.47938&lon=84.4386&title=ANM Training School, Jagdishpur,&dis=BHOJPUR', last_updated=datetime.datetime(2021, 5, 2, 17, 30), resources=[Resource(resource_type='TOTAL_BEDS', resource_description='hospital beds', resource_total='150', resource_available='147'), Resource(resource_type='ICU_WITHOUT_VENTILATOR', resource_description='icu beds', resource_total='0', resource_available='0')])
# Hospital(name='GNM School Sadar Hospital- Administrative Block', address='', district='SARAN', city='', state='BIHAR', location='/DailyDashboard/Map?lat=25.77994&lon=84.72945&title=GNM School Sadar Hospital- Administrative Block,&dis=SARAN', last_updated=datetime.datetime(2021, 5, 2, 13, 2), resources=[Resource(resource_type='TOTAL_BEDS', resource_description='hospital beds', resource_total='85', resource_available='21'), Resource(resource_type='ICU_WITHOUT_VENTILATOR', resource_description='icu beds', resource_total='0', resource_available='0')])
# Hospital(name='Girls Hostel, DIET, Sheohar', address='', district='SHEOHAR', city='', state='BIHAR', location='/DailyDashboard/Map?lat=26.50851&lon=85.3073&title=Girls Hostel, DIET, Sheohar,&dis=SHEOHAR', last_updated=datetime.datetime(2021, 5, 2, 12, 51), resources=[Resource(resource_type='TOTAL_BEDS', resource_description='hospital beds', resource_total='40', resource_available='22'), Resource(resource_type='ICU_WITHOUT_VENTILATOR', resource_description='icu beds', resource_total='0', resource_available='0')])
# Hospital(name='Mahila ITI, Shanti Nagar, Dumra, Mob-8544402048', address='', district='SITAMARHI', city='', state='BIHAR', location='/DailyDashboard/Map?lat=26.57438&lon=85.51507&title=Mahila ITI, Shanti Nagar, Dumra, Mob-8544402048,&dis=SITAMARHI', last_updated=datetime.datetime(2021, 4, 26, 12, 58), resources=[Resource(resource_type='TOTAL_BEDS', resource_description='hospital beds', resource_total='200', resource_available='180'), Resource(resource_type='ICU_WITHOUT_VENTILATOR', resource_description='icu beds', resource_total='0', resource_available='0')])
# Hospital(name='SDH Maharajganj', address='', district='SIWAN', city='', state='BIHAR', location='/DailyDashboard/Map?lat=26.22299&lon=84.34492&title=SDH Maharajganj,&dis=SIWAN', last_updated=datetime.datetime(2021, 5, 2, 11, 19), resources=[Resource(resource_type='TOTAL_BEDS', resource_description='hospital beds', resource_total='100', resource_available='55'), Resource(resource_type='ICU_WITHOUT_VENTILATOR', resource_description='icu beds', resource_total='0', resource_available='0')])
# Hospital(name='DH Supaul', address='', district='SUPAUL', city='', state='BIHAR', location='/DailyDashboard/Map?lat=26.11476&lon=86.59644&title=DH Supaul,&dis=SUPAUL', last_updated=datetime.datetime(2021, 5, 2, 16, 53), resources=[Resource(resource_type='TOTAL_BEDS', resource_description='hospital beds', resource_total='100', resource_available='97'), Resource(resource_type='ICU_WITHOUT_VENTILATOR', resource_description='icu beds', resource_total='0', resource_available='0')])
# Hospital(name='ANM Training School,Birpur', address='', district='SUPAUL', city='', state='BIHAR', location='/DailyDashboard/Map?lat=26.3&lon=87&title=ANM Training School,Birpur,&dis=SUPAUL', last_updated=datetime.datetime(2021, 4, 27, 12, 43), resources=[Resource(resource_type='TOTAL_BEDS', resource_description='hospital beds', resource_total='60', resource_available='60'), Resource(resource_type='ICU_WITHOUT_VENTILATOR', resource_description='icu beds', resource_total='0', resource_available='0')])
# Hospital(name='Buniyadi Kendra,Triveniganj', address='', district='SUPAUL', city='', state='BIHAR', location='/DailyDashboard/Map?lat=26.12689&lon=86.88052&title=Buniyadi Kendra,Triveniganj,&dis=SUPAUL', last_updated=datetime.datetime(2021, 4, 28, 10, 52), resources=[Resource(resource_type='TOTAL_BEDS', resource_description='hospital beds', resource_total='50', resource_available='50'), Resource(resource_type='ICU_WITHOUT_VENTILATOR', resource_description='icu beds', resource_total='0', resource_available='0')])
# Hospital(name='Govt Medical College Bettiah', address='', district='WEST CHAMPARAN', city='', state='BIHAR', location='/DailyDashboard/Map?lat=26.7958&lon=84.49969&title=Govt Medical College Bettiah,&dis=WEST CHAMPARAN', last_updated=datetime.datetime(2021, 4, 26, 13, 8), resources=[Resource(resource_type='TOTAL_BEDS', resource_description='hospital beds', resource_total='120', resource_available='120'), Resource(resource_type='ICU_WITHOUT_VENTILATOR', resource_description='icu beds', resource_total='12', resource_available='12')])
# Hospital(name='DCHC_DH_Jamui', address='', district='JAMUI', city='', state='BIHAR', location='/DailyDashboard/Map?lat=24.9241&lon=86.22427&title=DCHC_DH_Jamui,&dis=JAMUI', last_updated=datetime.datetime(2021, 4, 29, 12, 46), resources=[Resource(resource_type='TOTAL_BEDS', resource_description='hospital beds', resource_total='40', resource_available='18'), Resource(resource_type='ICU_WITHOUT_VENTILATOR', resource_description='icu beds', resource_total='0', resource_available='0')])
# Hospital(name='Administrative Block, GNM School, Mahuli, Gidhour', address='', district='JAMUI', city='', state='BIHAR', location='/DailyDashboard/Map?lat=24.85522&lon=86.30025&title=Administrative Block, GNM School, Mahuli, Gidhour,&dis=JAMUI', last_updated=datetime.datetime(2021, 4, 29, 12, 48), resources=[Resource(resource_type='TOTAL_BEDS', resource_description='hospital beds', resource_total='75', resource_available='75'), Resource(resource_type='ICU_WITHOUT_VENTILATOR', resource_description='icu beds', resource_total='0', resource_available='0')])
# Hospital(name='Sadar Hospital (GNM School) Jehanabad', address='', district='JEHANABAD', city='', state='BIHAR', location='/DailyDashboard/Map?lat=25.21045&lon=84.98568&title=Sadar Hospital (GNM School) Jehanabad,&dis=JEHANABAD', last_updated=datetime.datetime(2021, 5, 2, 11, 42), resources=[Resource(resource_type='TOTAL_BEDS', resource_description='hospital beds', resource_total='45', resource_available='12'), Resource(resource_type='ICU_WITHOUT_VENTILATOR', resource_description='icu beds', resource_total='5', resource_available='5')])
# Hospital(name='DH Kaimur', address='', district='KAIMUR', city='', state='BIHAR', location='/DailyDashboard/Map?lat=25.04019&lon=83.60819&title=DH Kaimur,&dis=KAIMUR', last_updated=datetime.datetime(2021, 4, 28, 19, 32), resources=[Resource(resource_type='TOTAL_BEDS', resource_description='hospital beds', resource_total='30', resource_available='0'), Resource(resource_type='ICU_WITHOUT_VENTILATOR', resource_description='icu beds', resource_total='0', resource_available='0')])
# Hospital(name='JKTMCH Madhepura', address='', district='MADHEPURA', city='', state='BIHAR', location='/DailyDashboard/Map?lat=25.95883&lon=86.79618&title=JKTMCH Madhepura,&dis=MADHEPURA', last_updated=datetime.datetime(2021, 5, 2, 18, 14), resources=[Resource(resource_type='TOTAL_BEDS', resource_description='hospital beds', resource_total='102', resource_available='28'), Resource(resource_type='ICU_WITHOUT_VENTILATOR', resource_description='icu beds', resource_total='19', resource_available='17')])
# Hospital(name='GNM SCHOOL KATRAKALA,MOHANAI', address='', district='KAIMUR', city='', state='BIHAR', location='/DailyDashboard/Map?lat=25.19015&lon=83.76973&title=GNM SCHOOL KATRAKALA,MOHANAI,&dis=KAIMUR', last_updated=datetime.datetime(2021, 4, 26, 8, 35), resources=[Resource(resource_type='TOTAL_BEDS', resource_description='hospital beds', resource_total='150', resource_available='134'), Resource(resource_type='ICU_WITHOUT_VENTILATOR', resource_description='icu beds', resource_total='0', resource_available='0')])
# Hospital(name='MGM Medical College & Hospital Kishanganj', address='', district='KISHANGANJ', city='', state='BIHAR', location='/DailyDashboard/Map?lat=26.10163&lon=87.97033&title=MGM Medical College & Hospital Kishanganj,&dis=KISHANGANJ', last_updated=datetime.datetime(2021, 5, 2, 8, 11), resources=[Resource(resource_type='TOTAL_BEDS', resource_description='hospital beds', resource_total='120', resource_available='120'), Resource(resource_type='ICU_WITHOUT_VENTILATOR', resource_description='icu beds', resource_total='0', resource_available='0')])
# Hospital(name='ANM SCHOOL BARSOI', address='', district='KATIHAR', city='', state='BIHAR', location='/DailyDashboard/Map?lat=25.62414&lon=87.93137&title=ANM SCHOOL BARSOI,&dis=KATIHAR', last_updated=datetime.datetime(2021, 4, 29, 17, 42), resources=[Resource(resource_type='TOTAL_BEDS', resource_description='hospital beds', resource_total='20', resource_available='20'), Resource(resource_type='ICU_WITHOUT_VENTILATOR', resource_description='icu beds', resource_total='0', resource_available='0')])
# Hospital(name='ANM SCHOOL MANIHARI', address='', district='KATIHAR', city='', state='BIHAR', location='/DailyDashboard/Map?lat=25.35244&lon=87.62388&title=ANM SCHOOL MANIHARI,&dis=KATIHAR', last_updated=datetime.datetime(2021, 4, 29, 17, 45), resources=[Resource(resource_type='TOTAL_BEDS', resource_description='hospital beds', resource_total='80', resource_available='80'), Resource(resource_type='ICU_WITHOUT_VENTILATOR', resource_description='icu beds', resource_total='0', resource_available='0')])
# Hospital(name='Katihar Medical College', address='', district='KATIHAR', city='', state='BIHAR', location='/DailyDashboard/Map?lat=25.58409&lon=87.54839&title=Katihar Medical College,&dis=KATIHAR', last_updated=None, resources=[Resource(resource_type='TOTAL_BEDS', resource_description='hospital beds', resource_total='20', resource_available='20'), Resource(resource_type='ICU_WITHOUT_VENTILATOR', resource_description='icu beds', resource_total='0', resource_available='0')])
# Hospital(name='GNM SCHOOL & HOSTEL', address='', district='KHAGARIA', city='', state='BIHAR', location='/DailyDashboard/Map?lat=25.508&lon=86.47575&title=GNM SCHOOL & HOSTEL,&dis=KHAGARIA', last_updated=datetime.datetime(2021, 4, 29, 14, 18), resources=[Resource(resource_type='TOTAL_BEDS', resource_description='hospital beds', resource_total='302', resource_available='302'), Resource(resource_type='ICU_WITHOUT_VENTILATOR', resource_description='icu beds', resource_total='0', resource_available='0')])
# Hospital(name='PMCH', address='', district='PATNA', city='', state='BIHAR', location='/DailyDashboard/Map?lat=25.57047&lon=85.09689&title=PMCH,&dis=PATNA', last_updated=datetime.datetime(2021, 5, 1, 12, 2), resources=[Resource(resource_type='TOTAL_BEDS', resource_description='hospital beds', resource_total='137', resource_available='11'), Resource(resource_type='ICU_WITHOUT_VENTILATOR', resource_description='icu beds', resource_total='25', resource_available='0')])
# Hospital(name='Rural Health Centre MGM Maheshbathna Kishanganj', address='', district='KISHANGANJ', city='', state='BIHAR', location='/DailyDashboard/Map?lat=26.21303&lon=87.98983&title=Rural Health Centre MGM Maheshbathna Kishanganj,&dis=KISHANGANJ', last_updated=datetime.datetime(2021, 5, 1, 12, 13), resources=[Resource(resource_type='TOTAL_BEDS', resource_description='hospital beds', resource_total='120', resource_available='107'), Resource(resource_type='ICU_WITHOUT_VENTILATOR', resource_description='icu beds', resource_total='0', resource_available='0')])
# Hospital(name='NMCH', address='', district='PATNA', city='', state='BIHAR', location='/DailyDashboard/Map?lat=25.60088&lon=85.1981&title=NMCH,&dis=PATNA', last_updated=datetime.datetime(2021, 5, 2, 10, 11), resources=[Resource(resource_type='TOTAL_BEDS', resource_description='hospital beds', resource_total='500', resource_available='143'), Resource(resource_type='ICU_WITHOUT_VENTILATOR', resource_description='icu beds', resource_total='36', resource_available='0')])
# Hospital(name='Sadar Hospital, Lakhisarai', address='', district='LAKHISARAI', city='', state='BIHAR', location='/DailyDashboard/Map?lat=25.07707&lon=86.13532&title=Sadar Hospital, Lakhisarai,&dis=LAKHISARAI', last_updated=datetime.datetime(2021, 4, 30, 8, 45), resources=[Resource(resource_type='TOTAL_BEDS', resource_description='hospital beds', resource_total='50', resource_available='32'), Resource(resource_type='ICU_WITHOUT_VENTILATOR', resource_description='icu beds', resource_total='10', resource_available='10')])
# Hospital(name='AIIMS', address='', district='PATNA', city='', state='BIHAR', location='/DailyDashboard/Map?lat=25.5723&lon=85.05405&title=AIIMS,&dis=PATNA', last_updated=datetime.datetime(2021, 5, 2, 9, 44), resources=[Resource(resource_type='TOTAL_BEDS', resource_description='hospital beds', resource_total='300', resource_available='2'), Resource(resource_type='ICU_WITHOUT_VENTILATOR', resource_description='icu beds', resource_total='60', resource_available='0')])
# Hospital(name='IGIMS Patna', address='', district='PATNA', city='', state='BIHAR', location='/DailyDashboard/Map?lat=25.6107&lon=85.08891&title=IGIMS Patna,&dis=PATNA', last_updated=datetime.datetime(2021, 5, 1, 12, 10), resources=[Resource(resource_type='TOTAL_BEDS', resource_description='hospital beds', resource_total='128', resource_available='0'), Resource(resource_type='ICU_WITHOUT_VENTILATOR', resource_description='icu beds', resource_total='53', resource_available='0')])
# Hospital(name='ANM TRANING SCHOOL JAINAGAR', address='', district='MADHUBANI', city='', state='BIHAR', location='/DailyDashboard/Map?lat=26.59774&lon=86.13763&title=ANM TRANING SCHOOL JAINAGAR,&dis=MADHUBANI', last_updated=datetime.datetime(2021, 5, 2, 11, 12), resources=[Resource(resource_type='TOTAL_BEDS', resource_description='hospital beds', resource_total='135', resource_available='135'), Resource(resource_type='ICU_WITHOUT_VENTILATOR', resource_description='icu beds', resource_total='0', resource_available='0')])
# Hospital(name='ANM Training School, Jhanjharpur', address='', district='MADHUBANI', city='', state='BIHAR', location='/DailyDashboard/Map?lat=0&lon=0&title=ANM Training School, Jhanjharpur,&dis=MADHUBANI', last_updated=datetime.datetime(2021, 5, 2, 10, 47), resources=[Resource(resource_type='TOTAL_BEDS', resource_description='hospital beds', resource_total='135', resource_available='127'), Resource(resource_type='ICU_WITHOUT_VENTILATOR', resource_description='icu beds', resource_total='0', resource_available='0')])
# Hospital(name='SDH Phulparas', address='', district='MADHUBANI', city='', state='BIHAR', location='/DailyDashboard/Map?lat=0&lon=0&title=SDH Phulparas,&dis=MADHUBANI', last_updated=datetime.datetime(2021, 4, 30, 14, 17), resources=[Resource(resource_type='TOTAL_BEDS', resource_description='hospital beds', resource_total='48', resource_available='48'), Resource(resource_type='ICU_WITHOUT_VENTILATOR', resource_description='icu beds', resource_total='0', resource_available='0')])
# Hospital(name='VIIMS, Pawapuri Nalanda', address='', district='NALANDA', city='', state='BIHAR', location='/DailyDashboard/Map?lat=25.09014&lon=85.54263&title=VIIMS, Pawapuri Nalanda,&dis=NALANDA', last_updated=datetime.datetime(2021, 4, 29, 12, 30), resources=[Resource(resource_type='TOTAL_BEDS', resource_description='hospital beds', resource_total='132', resource_available='12'), Resource(resource_type='ICU_WITHOUT_VENTILATOR', resource_description='icu beds', resource_total='12', resource_available='0')])
# Hospital(name='ANMCH Gaya', address='', district='GAYA', city='', state='BIHAR', location='/DailyDashboard/Map?lat=24.80389&lon=85.00121&title=ANMCH Gaya,&dis=GAYA', last_updated=datetime.datetime(2021, 5, 2, 16, 7), resources=[Resource(resource_type='TOTAL_BEDS', resource_description='hospital beds', resource_total='462', resource_available='287'), Resource(resource_type='ICU_WITHOUT_VENTILATOR', resource_description='icu beds', resource_total='28', resource_available='16')])
# Hospital(name='GNM, School, Sadar Munger', address='', district='MUNGER', city='', state='BIHAR', location='/DailyDashboard/Map?lat=25.36985&lon=86.48872&title=GNM, School, Sadar Munger,&dis=MUNGER', last_updated=datetime.datetime(2021, 5, 2, 11, 54), resources=[Resource(resource_type='TOTAL_BEDS', resource_description='hospital beds', resource_total='160', resource_available='148'), Resource(resource_type='ICU_WITHOUT_VENTILATOR', resource_description='icu beds', resource_total='0', resource_available='0')])
# Hospital(name='APHC Belbihma Tarapur', address='', district='MUNGER', city='', state='BIHAR', location='/DailyDashboard/Map?lat=25.06853&lon=86.62691&title=APHC Belbihma Tarapur,&dis=MUNGER', last_updated=datetime.datetime(2021, 4, 26, 12, 48), resources=[Resource(resource_type='TOTAL_BEDS', resource_description='hospital beds', resource_total='20', resource_available='20'), Resource(resource_type='ICU_WITHOUT_VENTILATOR', resource_description='icu beds', resource_total='0', resource_available='0')])
# Hospital(name='JLNMCH BHAGALPUR', address='', district='BHAGALPUR', city='', state='BIHAR', location='/DailyDashboard/Map?lat=25.26287&lon=87.00124&title=JLNMCH BHAGALPUR,&dis=BHAGALPUR', last_updated=datetime.datetime(2021, 5, 2, 13, 35), resources=[Resource(resource_type='TOTAL_BEDS', resource_description='hospital beds', resource_total='700', resource_available='274'), Resource(resource_type='ICU_WITHOUT_VENTILATOR', resource_description='icu beds', resource_total='36', resource_available='0')])
# Hospital(name='ANM Training School , SDH Tarapur', address='', district='MUNGER', city='', state='BIHAR', location='/DailyDashboard/Map?lat=25.10075&lon=86.67118&title=ANM Training School , SDH Tarapur,&dis=MUNGER', last_updated=datetime.datetime(2021, 5, 1, 11, 43), resources=[Resource(resource_type='TOTAL_BEDS', resource_description='hospital beds', resource_total='50', resource_available='44'), Resource(resource_type='ICU_WITHOUT_VENTILATOR', resource_description='icu beds', resource_total='0', resource_available='0')])
# Hospital(name='DMCH Darbhanga', address='', district='DARBHANGA', city='', state='BIHAR', location='/DailyDashboard/Map?lat=26.12875&lon=85.8964&title=DMCH Darbhanga,&dis=DARBHANGA', last_updated=datetime.datetime(2021, 5, 2, 12, 48), resources=[Resource(resource_type='TOTAL_BEDS', resource_description='hospital beds', resource_total='127', resource_available='18'), Resource(resource_type='ICU_WITHOUT_VENTILATOR', resource_description='icu beds', resource_total='7', resource_available='0')])
# Hospital(name='Narayan Medical College & Hospital Jamuhar', address='', district='ROHTAS', city='', state='BIHAR', location='/DailyDashboard/Map?lat=24.5637&lon=84.65&title=Narayan Medical College & Hospital Jamuhar,&dis=ROHTAS', last_updated=datetime.datetime(2021, 5, 1, 11, 21), resources=[Resource(resource_type='TOTAL_BEDS', resource_description='hospital beds', resource_total='100', resource_available='28'), Resource(resource_type='ICU_WITHOUT_VENTILATOR', resource_description='icu beds', resource_total='20', resource_available='20')])
# Hospital(name='Glocal Hospital', address='', district='MUZAFFARPUR', city='', state='BIHAR', location='/DailyDashboard/Map?lat=26.1495&lon=85.34301&title=Glocal Hospital,&dis=MUZAFFARPUR', last_updated=datetime.datetime(2021, 5, 2, 18, 14), resources=[Resource(resource_type='TOTAL_BEDS', resource_description='hospital beds', resource_total='100', resource_available='79'), Resource(resource_type='ICU_WITHOUT_VENTILATOR', resource_description='icu beds', resource_total='0', resource_available='0')])
# Hospital(name='SDH Hilsa', address='', district='NALANDA', city='', state='BIHAR', location='/DailyDashboard/Map?lat=25.31577&lon=85.27458&title=SDH Hilsa,&dis=NALANDA', last_updated=None, resources=[Resource(resource_type='TOTAL_BEDS', resource_description='hospital beds', resource_total='55', resource_available='55'), Resource(resource_type='ICU_WITHOUT_VENTILATOR', resource_description='icu beds', resource_total='0', resource_available='0')])
# Hospital(name='SDH Rajgir', address='', district='NALANDA', city='', state='BIHAR', location='/DailyDashboard/Map?lat=25.02661&lon=85.42351&title=SDH Rajgir,&dis=NALANDA', last_updated=None, resources=[Resource(resource_type='TOTAL_BEDS', resource_description='hospital beds', resource_total='55', resource_available='55'), Resource(resource_type='ICU_WITHOUT_VENTILATOR', resource_description='icu beds', resource_total='0', resource_available='0')])
# Hospital(name='District Hospital-Bgp', address='', district='BHAGALPUR', city='', state='BIHAR', location='/DailyDashboard/Map?lat=0&lon=0&title=District Hospital-Bgp,&dis=BHAGALPUR', last_updated=datetime.datetime(2021, 5, 2, 10, 44), resources=[Resource(resource_type='TOTAL_BEDS', resource_description='hospital beds', resource_total='90', resource_available='69'), Resource(resource_type='ICU_WITHOUT_VENTILATOR', resource_description='icu beds', resource_total='0', resource_available='0')])
# Hospital(name='ANM Training School, Narkatiyaganj', address='', district='WEST CHAMPARAN', city='', state='BIHAR', location='/DailyDashboard/Map?lat=27.11519&lon=84.46702&title=ANM Training School, Narkatiyaganj,&dis=WEST CHAMPARAN', last_updated=datetime.datetime(2021, 4, 30, 17, 42), resources=[Resource(resource_type='TOTAL_BEDS', resource_description='hospital beds', resource_total='100', resource_available='100'), Resource(resource_type='ICU_WITHOUT_VENTILATOR', resource_description='icu beds', resource_total='0', resource_available='0')])
# Hospital(name='ANM Training School, Bagaha 1', address='', district='WEST CHAMPARAN', city='', state='BIHAR', location='/DailyDashboard/Map?lat=27.09622&lon=84.09232&title=ANM Training School, Bagaha 1,&dis=WEST CHAMPARAN', last_updated=None, resources=[Resource(resource_type='TOTAL_BEDS', resource_description='hospital beds', resource_total='100', resource_available='100'), Resource(resource_type='ICU_WITHOUT_VENTILATOR', resource_description='icu beds', resource_total='0', resource_available='0')])
# Hospital(name='ANM Training School, Patori', address='', district='SAMASTIPUR', city='', state='BIHAR', location='/DailyDashboard/Map?lat=25.63363&lon=85.59476&title=ANM Training School, Patori,&dis=SAMASTIPUR', last_updated=datetime.datetime(2021, 5, 2, 17, 48), resources=[Resource(resource_type='TOTAL_BEDS', resource_description='hospital beds', resource_total='60', resource_available='47'), Resource(resource_type='ICU_WITHOUT_VENTILATOR', resource_description='icu beds', resource_total='0', resource_available='0')])
# Hospital(name='NSMCH, BIHTA', address='', district='PATNA', city='', state='BIHAR', location='/DailyDashboard/Map?lat=25.55666&lon=84.86855&title=NSMCH, BIHTA,&dis=PATNA', last_updated=datetime.datetime(2021, 5, 2, 17, 26), resources=[Resource(resource_type='TOTAL_BEDS', resource_description='hospital beds', resource_total='40', resource_available='0'), Resource(resource_type='ICU_WITHOUT_VENTILATOR', resource_description='icu beds', resource_total='16', resource_available='0')])
# Hospital(name='HOSTEL BLOCK GNM SCHOOL BOYS HOSTEL  SADAR HOSPITAL ARWAL', address='', district='ARWAL', city='', state='BIHAR', location='/DailyDashboard/Map?lat=25.2324&lon=84.678&title=HOSTEL BLOCK GNM SCHOOL BOYS HOSTEL  SADAR HOSPITAL ARWAL,&dis=ARWAL', last_updated=datetime.datetime(2021, 4, 26, 10, 52), resources=[Resource(resource_type='TOTAL_BEDS', resource_description='hospital beds', resource_total='90', resource_available='90'), Resource(resource_type='ICU_WITHOUT_VENTILATOR', resource_description='icu beds', resource_total='0', resource_available='0')])
# Hospital(name='Ram Lakan Singh Yadav College Hostel', address='', district='AURANGABAD', city='', state='BIHAR', location='/DailyDashboard/Map?lat=50&lon=50&title=Ram Lakan Singh Yadav College Hostel,&dis=AURANGABAD', last_updated=datetime.datetime(2021, 5, 1, 15, 12), resources=[Resource(resource_type='TOTAL_BEDS', resource_description='hospital beds', resource_total='50', resource_available='50'), Resource(resource_type='ICU_WITHOUT_VENTILATOR', resource_description='icu beds', resource_total='0', resource_available='0')])
# Hospital(name='Mahavir Agrasen Seva Sadan', address='', district='BEGUSARAI', city='', state='BIHAR', location='/DailyDashboard/Map?lat=0&lon=0&title=Mahavir Agrasen Seva Sadan,&dis=BEGUSARAI', last_updated=datetime.datetime(2021, 5, 2, 17, 17), resources=[Resource(resource_type='TOTAL_BEDS', resource_description='hospital beds', resource_total='25', resource_available='0'), Resource(resource_type='ICU_WITHOUT_VENTILATOR', resource_description='icu beds', resource_total='1', resource_available='0')])
# Hospital(name='Govt Raen Basera', address='', district='KATIHAR', city='', state='BIHAR', location='/DailyDashboard/Map?lat=25.5393&lon=87.56721&title=Govt Raen Basera,&dis=KATIHAR', last_updated=datetime.datetime(2021, 4, 30, 16, 18), resources=[Resource(resource_type='TOTAL_BEDS', resource_description='hospital beds', resource_total='20', resource_available='20'), Resource(resource_type='ICU_WITHOUT_VENTILATOR', resource_description='icu beds', resource_total='0', resource_available='0')])
# Hospital(name='Minority Girls hostel , T.P. College Madhepura', address='', district='MADHEPURA', city='', state='BIHAR', location='/DailyDashboard/Map?lat=25.93298&lon=86.79884&title=Minority Girls hostel , T.P. College Madhepura,&dis=MADHEPURA', last_updated=datetime.datetime(2021, 5, 2, 11, 23), resources=[Resource(resource_type='TOTAL_BEDS', resource_description='hospital beds', resource_total='100', resource_available='83'), Resource(resource_type='ICU_WITHOUT_VENTILATOR', resource_description='icu beds', resource_total='0', resource_available='0')])
# Hospital(name='CHC RIGA', address='', district='SITAMARHI', city='', state='BIHAR', location='/DailyDashboard/Map?lat=26.64693&lon=85.42951&title=CHC RIGA,&dis=SITAMARHI', last_updated=datetime.datetime(2021, 4, 26, 12, 58), resources=[Resource(resource_type='TOTAL_BEDS', resource_description='hospital beds', resource_total='20', resource_available='20'), Resource(resource_type='ICU_WITHOUT_VENTILATOR', resource_description='icu beds', resource_total='0', resource_available='0')])
# Hospital(name='CHC BAIRGANIYA', address='', district='SITAMARHI', city='', state='BIHAR', location='/DailyDashboard/Map?lat=26.73928&lon=85.27759&title=CHC BAIRGANIYA,&dis=SITAMARHI', last_updated=datetime.datetime(2021, 4, 26, 12, 59), resources=[Resource(resource_type='TOTAL_BEDS', resource_description='hospital beds', resource_total='20', resource_available='20'), Resource(resource_type='ICU_WITHOUT_VENTILATOR', resource_description='icu beds', resource_total='0', resource_available='0')])
# Hospital(name='CHC BAJPATTI', address='', district='SITAMARHI', city='', state='BIHAR', location='/DailyDashboard/Map?lat=26.54566&lon=85.62218&title=CHC BAJPATTI,&dis=SITAMARHI', last_updated=datetime.datetime(2021, 4, 26, 13, 0), resources=[Resource(resource_type='TOTAL_BEDS', resource_description='hospital beds', resource_total='20', resource_available='20'), Resource(resource_type='ICU_WITHOUT_VENTILATOR', resource_description='icu beds', resource_total='0', resource_available='0')])
# Hospital(name='CHC BATHNAHA', address='', district='SITAMARHI', city='', state='BIHAR', location='/DailyDashboard/Map?lat=26.63726&lon=85.58771&title=CHC BATHNAHA,&dis=SITAMARHI', last_updated=datetime.datetime(2021, 4, 26, 13, 1), resources=[Resource(resource_type='TOTAL_BEDS', resource_description='hospital beds', resource_total='20', resource_available='20'), Resource(resource_type='ICU_WITHOUT_VENTILATOR', resource_description='icu beds', resource_total='0', resource_available='0')])
# Hospital(name='CHC BELSAND', address='', district='SITAMARHI', city='', state='BIHAR', location='/DailyDashboard/Map?lat=26.43942&lon=85.40022&title=CHC BELSAND,&dis=SITAMARHI', last_updated=datetime.datetime(2021, 4, 26, 13, 1), resources=[Resource(resource_type='TOTAL_BEDS', resource_description='hospital beds', resource_total='20', resource_available='20'), Resource(resource_type='ICU_WITHOUT_VENTILATOR', resource_description='icu beds', resource_total='0', resource_available='0')])
# Hospital(name='CHC BOKHRA', address='', district='SITAMARHI', city='', state='BIHAR', location='/DailyDashboard/Map?lat=26.35528&lon=85.67496&title=CHC BOKHRA,&dis=SITAMARHI', last_updated=datetime.datetime(2021, 4, 26, 13, 2), resources=[Resource(resource_type='TOTAL_BEDS', resource_description='hospital beds', resource_total='20', resource_available='20'), Resource(resource_type='ICU_WITHOUT_VENTILATOR', resource_description='icu beds', resource_total='0', resource_available='0')])
# Hospital(name='CHC CHORAUT', address='', district='SITAMARHI', city='', state='BIHAR', location='/DailyDashboard/Map?lat=26.53503&lon=85.79568&title=CHC CHORAUT,&dis=SITAMARHI', last_updated=datetime.datetime(2021, 4, 26, 13, 2), resources=[Resource(resource_type='TOTAL_BEDS', resource_description='hospital beds', resource_total='20', resource_available='20'), Resource(resource_type='ICU_WITHOUT_VENTILATOR', resource_description='icu beds', resource_total='0', resource_available='0')])
# Hospital(name='PHC DUMRA', address='', district='SITAMARHI', city='', state='BIHAR', location='/DailyDashboard/Map?lat=26.56609&lon=85.52316&title=PHC DUMRA,&dis=SITAMARHI', last_updated=datetime.datetime(2021, 4, 26, 13, 3), resources=[Resource(resource_type='TOTAL_BEDS', resource_description='hospital beds', resource_total='10', resource_available='10'), Resource(resource_type='ICU_WITHOUT_VENTILATOR', resource_description='icu beds', resource_total='0', resource_available='0')])
# Hospital(name='R H MAJORGANJ', address='', district='SITAMARHI', city='', state='BIHAR', location='/DailyDashboard/Map?lat=26.74964&lon=85.42755&title=R H MAJORGANJ,&dis=SITAMARHI', last_updated=datetime.datetime(2021, 4, 26, 13, 3), resources=[Resource(resource_type='TOTAL_BEDS', resource_description='hospital beds', resource_total='15', resource_available='15'), Resource(resource_type='ICU_WITHOUT_VENTILATOR', resource_description='icu beds', resource_total='0', resource_available='0')])
# Hospital(name='CHC NANPUR', address='', district='SITAMARHI', city='', state='BIHAR', location='/DailyDashboard/Map?lat=26.43797&lon=85.6664&title=CHC NANPUR,&dis=SITAMARHI', last_updated=datetime.datetime(2021, 4, 26, 13, 5), resources=[Resource(resource_type='TOTAL_BEDS', resource_description='hospital beds', resource_total='20', resource_available='20'), Resource(resource_type='ICU_WITHOUT_VENTILATOR', resource_description='icu beds', resource_total='0', resource_available='0')])
# Hospital(name='CHC PARIHAR', address='', district='SITAMARHI', city='', state='BIHAR', location='/DailyDashboard/Map?lat=26.71354&lon=85.68128&title=CHC PARIHAR,&dis=SITAMARHI', last_updated=datetime.datetime(2021, 4, 26, 13, 6), resources=[Resource(resource_type='TOTAL_BEDS', resource_description='hospital beds', resource_total='20', resource_available='20'), Resource(resource_type='ICU_WITHOUT_VENTILATOR', resource_description='icu beds', resource_total='0', resource_available='0')])
# Hospital(name='PHC PARSAUNI', address='', district='SITAMARHI', city='', state='BIHAR', location='/DailyDashboard/Map?lat=26.50589&lon=85.40332&title=PHC PARSAUNI,&dis=SITAMARHI', last_updated=datetime.datetime(2021, 4, 26, 13, 6), resources=[Resource(resource_type='TOTAL_BEDS', resource_description='hospital beds', resource_total='10', resource_available='10'), Resource(resource_type='ICU_WITHOUT_VENTILATOR', resource_description='icu beds', resource_total='0', resource_available='0')])
# Hospital(name='PHC PUPRI', address='', district='SITAMARHI', city='', state='BIHAR', location='/DailyDashboard/Map?lat=26.46265&lon=85.70105&title=PHC PUPRI,&dis=SITAMARHI', last_updated=datetime.datetime(2021, 4, 26, 13, 6), resources=[Resource(resource_type='TOTAL_BEDS', resource_description='hospital beds', resource_total='10', resource_available='10'), Resource(resource_type='ICU_WITHOUT_VENTILATOR', resource_description='icu beds', resource_total='0', resource_available='0')])
# Hospital(name='CHC RUNISAIDPUR', address='', district='SITAMARHI', city='', state='BIHAR', location='/DailyDashboard/Map?lat=26.38983&lon=85.50756&title=CHC RUNISAIDPUR,&dis=SITAMARHI', last_updated=datetime.datetime(2021, 4, 26, 13, 7), resources=[Resource(resource_type='TOTAL_BEDS', resource_description='hospital beds', resource_total='20', resource_available='20'), Resource(resource_type='ICU_WITHOUT_VENTILATOR', resource_description='icu beds', resource_total='0', resource_available='0')])
# Hospital(name='CHC SONBARSA', address='', district='SITAMARHI', city='', state='BIHAR', location='/DailyDashboard/Map?lat=26.84179&lon=85.5778&title=CHC SONBARSA,&dis=SITAMARHI', last_updated=datetime.datetime(2021, 4, 26, 13, 7), resources=[Resource(resource_type='TOTAL_BEDS', resource_description='hospital beds', resource_total='20', resource_available='20'), Resource(resource_type='ICU_WITHOUT_VENTILATOR', resource_description='icu beds', resource_total='0', resource_available='0')])
# ...
# Hospital(name='ESIC, BIHTA', address='', district='PATNA', city='', state='BIHAR', location='/DailyDashboard/Map?lat=0&lon=0&title=ESIC, BIHTA,&dis=PATNA', last_updated=datetime.datetime(2021, 5, 2, 16, 57), resources=[Resource(resource_type='TOTAL_BEDS', resource_description='hospital beds', resource_total='60', resource_available='0'), Resource(resource_type='ICU_WITHOUT_VENTILATOR', resource_description='icu beds', resource_total='0', resource_available='0')])
# Hospital(name='Ambedkar Balika Chhatrawas', address='', district='VAISHALI', city='', state='BIHAR', location='/DailyDashboard/Map?lat=25.72001&lon=85.2403&title=Ambedkar Balika Chhatrawas,&dis=VAISHALI', last_updated=datetime.datetime(2021, 5, 2, 13, 16), resources=[Resource(resource_type='TOTAL_BEDS', resource_description='hospital beds', resource_total='90', resource_available='67'), Resource(resource_type='ICU_WITHOUT_VENTILATOR', resource_description='icu beds', resource_total='0', resource_available='0')])
# Hospital(name='Vishwamitra Hospital Golamber Buxar', address='', district='BUXAR', city='', state='BIHAR', location='/DailyDashboard/Map?lat=0&lon=0&title=Vishwamitra Hospital Golamber Buxar,&dis=BUXAR', last_updated=datetime.datetime(2021, 5, 2, 12, 11), resources=[Resource(resource_type='TOTAL_BEDS', resource_description='hospital beds', resource_total='20', resource_available='20'), Resource(resource_type='ICU_WITHOUT_VENTILATOR', resource_description='icu beds', resource_total='0', resource_available='0')])
# Hospital(name='Budha Emergency Hospital', address='', district='GAYA', city='', state='BIHAR', location='/DailyDashboard/Map?lat=0&lon=0&title=Budha Emergency Hospital,&dis=GAYA', last_updated=datetime.datetime(2021, 5, 2, 14, 0), resources=[Resource(resource_type='TOTAL_BEDS', resource_description='hospital beds', resource_total='20', resource_available='5'), Resource(resource_type='ICU_WITHOUT_VENTILATOR', resource_description='icu beds', resource_total='0', resource_available='0')])
# Hospital(name='Baishnavi Hospital', address='', district='GAYA', city='', state='BIHAR', location='/DailyDashboard/Map?lat=0&lon=0&title=Baishnavi Hospital,&dis=GAYA', last_updated=datetime.datetime(2021, 5, 2, 14, 0), resources=[Resource(resource_type='TOTAL_BEDS', resource_description='hospital beds', resource_total='10', resource_available='0'), Resource(resource_type='ICU_WITHOUT_VENTILATOR', resource_description='icu beds', resource_total='0', resource_available='0')])
# Hospital(name='Sri Ram Hospital', address='', district='GAYA', city='', state='BIHAR', location='/DailyDashboard/Map?lat=0&lon=0&title=Sri Ram Hospital,&dis=GAYA', last_updated=datetime.datetime(2021, 5, 2, 14, 1), resources=[Resource(resource_type='TOTAL_BEDS', resource_description='hospital beds', resource_total='8', resource_available='3'), Resource(resource_type='ICU_WITHOUT_VENTILATOR', resource_description='icu beds', resource_total='0', resource_available='0')])
# Hospital(name='KRISHNA HOSPITAL, MAHUA', address='', district='VAISHALI', city='', state='BIHAR', location='/DailyDashboard/Map?lat=0&lon=0&title=KRISHNA HOSPITAL, MAHUA,&dis=VAISHALI', last_updated=datetime.datetime(2021, 4, 28, 13, 11), resources=[Resource(resource_type='TOTAL_BEDS', resource_description='hospital beds', resource_total='20', resource_available='20'), Resource(resource_type='ICU_WITHOUT_VENTILATOR', resource_description='icu beds', resource_total='6', resource_available='6')])
# Hospital(name='Rainbow Hospital', address='', district='GAYA', city='', state='BIHAR', location='/DailyDashboard/Map?lat=0&lon=0&title=Rainbow Hospital,&dis=GAYA', last_updated=datetime.datetime(2021, 5, 2, 14, 1), resources=[Resource(resource_type='TOTAL_BEDS', resource_description='hospital beds', resource_total='6', resource_available='0'), Resource(resource_type='ICU_WITHOUT_VENTILATOR', resource_description='icu beds', resource_total='0', resource_available='0')])
# Hospital(name='PATLIPUTRA MULTI PLUS', address='', district='PATNA', city='', state='BIHAR', location='/DailyDashboard/Map?lat=0&lon=0&title=PATLIPUTRA MULTI PLUS,&dis=PATNA', last_updated=datetime.datetime(2021, 5, 2, 11, 2), resources=[Resource(resource_type='TOTAL_BEDS', resource_description='hospital beds', resource_total='10', resource_available='0'), Resource(resource_type='ICU_WITHOUT_VENTILATOR', resource_description='icu beds', resource_total='5', resource_available='0')])
# Hospital(name='SAMRAT EMERGENCY & TRAUMA HOSPITAL', address='', district='PATNA', city='', state='BIHAR', location='/DailyDashboard/Map?lat=0&lon=0&title=SAMRAT EMERGENCY & TRAUMA HOSPITAL,&dis=PATNA', last_updated=datetime.datetime(2021, 4, 29, 11, 46), resources=[Resource(resource_type='TOTAL_BEDS', resource_description='hospital beds', resource_total='16', resource_available='16'), Resource(resource_type='ICU_WITHOUT_VENTILATOR', resource_description='icu beds', resource_total='10', resource_available='10')])
# Hospital(name='DHAMA SUPERSPECIALITY HOSPITAL', address='', district='PATNA', city='', state='BIHAR', location='/DailyDashboard/Map?lat=0&lon=0&title=DHAMA SUPERSPECIALITY HOSPITAL,&dis=PATNA', last_updated=datetime.datetime(2021, 4, 29, 12, 0), resources=[Resource(resource_type='TOTAL_BEDS', resource_description='hospital beds', resource_total='20', resource_available='20'), Resource(resource_type='ICU_WITHOUT_VENTILATOR', resource_description='icu beds', resource_total='15', resource_available='15')])
# Hospital(name='JEEVAN DEEP HOSPITAL', address='', district='PATNA', city='', state='BIHAR', location='/DailyDashboard/Map?lat=0&lon=0&title=JEEVAN DEEP HOSPITAL,&dis=PATNA', last_updated=datetime.datetime(2021, 4, 29, 12, 13), resources=[Resource(resource_type='TOTAL_BEDS', resource_description='hospital beds', resource_total='20', resource_available='20'), Resource(resource_type='ICU_WITHOUT_VENTILATOR', resource_description='icu beds', resource_total='10', resource_available='10')])
# Hospital(name='SHIVAM HOSPITAL & RESEARCH INSTITUTE PVT', address='', district='PATNA', city='', state='BIHAR', location='/DailyDashboard/Map?lat=0&lon=0&title=SHIVAM HOSPITAL & RESEARCH INSTITUTE PVT,&dis=PATNA', last_updated=datetime.datetime(2021, 4, 29, 12, 23), resources=[Resource(resource_type='TOTAL_BEDS', resource_description='hospital beds', resource_total='26', resource_available='26'), Resource(resource_type='ICU_WITHOUT_VENTILATOR', resource_description='icu beds', resource_total='0', resource_available='0')])
# Hospital(name='MEDIBLESS HOSPITAL PVT LTD', address='', district='PATNA', city='', state='BIHAR', location='/DailyDashboard/Map?lat=0&lon=0&title=MEDIBLESS HOSPITAL PVT LTD,&dis=PATNA', last_updated=datetime.datetime(2021, 4, 29, 12, 32), resources=[Resource(resource_type='TOTAL_BEDS', resource_description='hospital beds', resource_total='10', resource_available='10'), Resource(resource_type='ICU_WITHOUT_VENTILATOR', resource_description='icu beds', resource_total='6', resource_available='6')])
# Hospital(name='MYERA MEDILAND HOSPITAL PVT. LTD.', address='', district='BEGUSARAI', city='', state='BIHAR', location='/DailyDashboard/Map?lat=0&lon=0&title=MYERA MEDILAND HOSPITAL PVT. LTD.,&dis=BEGUSARAI', last_updated=datetime.datetime(2021, 5, 2, 10, 40), resources=[Resource(resource_type='TOTAL_BEDS', resource_description='hospital beds', resource_total='15', resource_available='9'), Resource(resource_type='ICU_WITHOUT_VENTILATOR', resource_description='icu beds', resource_total='15', resource_available='9')])
# Hospital(name='Medcure  Health Hospital', address='', district='WEST CHAMPARAN', city='', state='BIHAR', location='/DailyDashboard/Map?lat=26.79667&lon=84.49362&title=Medcure  Health Hospital,&dis=WEST CHAMPARAN', last_updated=datetime.datetime(2021, 5, 2, 12, 18), resources=[Resource(resource_type='TOTAL_BEDS', resource_description='hospital beds', resource_total='20', resource_available='20'), Resource(resource_type='ICU_WITHOUT_VENTILATOR', resource_description='icu beds', resource_total='7', resource_available='7')])
# Hospital(name='Nav Jyoti Hospital Purnea', address='', district='PURNIA', city='', state='BIHAR', location='/DailyDashboard/Map?lat=0&lon=0&title=Nav Jyoti Hospital Purnea,&dis=PURNIA', last_updated=datetime.datetime(2021, 5, 2, 19, 48), resources=[Resource(resource_type='TOTAL_BEDS', resource_description='hospital beds', resource_total='6', resource_available='1'), Resource(resource_type='ICU_WITHOUT_VENTILATOR', resource_description='icu beds', resource_total='0', resource_available='0')])
# Hospital(name='Simanchal Emergency Hospital', address='', district='PURNIA', city='', state='BIHAR', location='/DailyDashboard/Map?lat=0&lon=0&title=Simanchal Emergency Hospital,&dis=PURNIA', last_updated=datetime.datetime(2021, 5, 1, 19, 1), resources=[Resource(resource_type='TOTAL_BEDS', resource_description='hospital beds', resource_total='15', resource_available='7'), Resource(resource_type='ICU_WITHOUT_VENTILATOR', resource_description='icu beds', resource_total='0', resource_available='0')])
# Hospital(name='ALFA HOSPITAL', address='', district='PURNIA', city='', state='BIHAR', location='/DailyDashboard/Map?lat=0&lon=0&title=ALFA HOSPITAL,&dis=PURNIA', last_updated=datetime.datetime(2021, 5, 2, 19, 44), resources=[Resource(resource_type='TOTAL_BEDS', resource_description='hospital beds', resource_total='10', resource_available='0'), Resource(resource_type='ICU_WITHOUT_VENTILATOR', resource_description='icu beds', resource_total='0', resource_available='0')])
# Hospital(name='JEEVAN_MULTISPECILITY', address='', district='PURNIA', city='', state='BIHAR', location='/DailyDashboard/Map?lat=0&lon=0&title=JEEVAN_MULTISPECILITY,&dis=PURNIA', last_updated=datetime.datetime(2021, 5, 1, 19, 2), resources=[Resource(resource_type='TOTAL_BEDS', resource_description='hospital beds', resource_total='17', resource_available='12'), Resource(resource_type='ICU_WITHOUT_VENTILATOR', resource_description='icu beds', resource_total='0', resource_available='0')])
# Hospital(name='Sadar Phc Nawada', address='', district='NAWADA', city='', state='BIHAR', location='/DailyDashboard/Map?lat=24.89899&lon=85.54077&title=Sadar Phc Nawada,&dis=NAWADA', last_updated=datetime.datetime(2021, 5, 2, 19, 6), resources=[Resource(resource_type='TOTAL_BEDS', resource_description='hospital beds', resource_total='75', resource_available='75'), Resource(resource_type='ICU_WITHOUT_VENTILATOR', resource_description='icu beds', resource_total='0', resource_available='0')])
# Hospital(name='Narayana Emergency Hospital', address='', district='SAMASTIPUR', city='', state='BIHAR', location='/DailyDashboard/Map?lat=25.8598&lon=85.7866&title=Narayana Emergency Hospital,&dis=SAMASTIPUR', last_updated=datetime.datetime(2021, 5, 2, 17, 50), resources=[Resource(resource_type='TOTAL_BEDS', resource_description='hospital beds', resource_total='10', resource_available='0'), Resource(resource_type='ICU_WITHOUT_VENTILATOR', resource_description='icu beds', resource_total='0', resource_available='0')])
# Hospital(name='Sri Narayan Hospital', address='', district='GAYA', city='', state='BIHAR', location='/DailyDashboard/Map?lat=0&lon=0&title=Sri Narayan Hospital,&dis=GAYA', last_updated=datetime.datetime(2021, 5, 2, 22, 31), resources=[Resource(resource_type='TOTAL_BEDS', resource_description='hospital beds', resource_total='10', resource_available='10'), Resource(resource_type='ICU_WITHOUT_VENTILATOR', resource_description='icu beds', resource_total='0', resource_available='0')])
# Hospital(name='Gaya Central', address='', district='GAYA', city='', state='BIHAR', location='/DailyDashboard/Map?lat=0&lon=0&title=Gaya Central,&dis=GAYA', last_updated=datetime.datetime(2021, 5, 2, 22, 33), resources=[Resource(resource_type='TOTAL_BEDS', resource_description='hospital beds', resource_total='8', resource_available='8'), Resource(resource_type='ICU_WITHOUT_VENTILATOR', resource_description='icu beds', resource_total='0', resource_available='0')])
# Hospital(name='Aslam Mano Hospital', address='', district='GAYA', city='', state='BIHAR', location='/DailyDashboard/Map?lat=0&lon=0&title=Aslam Mano Hospital,&dis=GAYA', last_updated=datetime.datetime(2021, 5, 2, 22, 35), resources=[Resource(resource_type='TOTAL_BEDS', resource_description='hospital beds', resource_total='6', resource_available='6'), Resource(resource_type='ICU_WITHOUT_VENTILATOR', resource_description='icu beds', resource_total='0', resource_available='0')])
# Hospital(name='PPR Arogyam', address='', district='GAYA', city='', state='BIHAR', location='/DailyDashboard/Map?lat=0&lon=0&title=PPR Arogyam,&dis=GAYA', last_updated=datetime.datetime(2021, 5, 2, 22, 36), resources=[Resource(resource_type='TOTAL_BEDS', resource_description='hospital beds', resource_total='6', resource_available='6'), Resource(resource_type='ICU_WITHOUT_VENTILATOR', resource_description='icu beds', resource_total='0', resource_available='0')])
# Hospital(name='New DSR Hospital', address='', district='GAYA', city='', state='BIHAR', location='/DailyDashboard/Map?lat=0&lon=0&title=New DSR Hospital,&dis=GAYA', last_updated=datetime.datetime(2021, 5, 2, 22, 38), resources=[Resource(resource_type='TOTAL_BEDS', resource_description='hospital beds', resource_total='8', resource_available='8'), Resource(resource_type='ICU_WITHOUT_VENTILATOR', resource_description='icu beds', resource_total='0', resource_available='0')])
# Hospital(name='Om Sai Nursing Home', address='', district='GAYA', city='', state='BIHAR', location='/DailyDashboard/Map?lat=0&lon=0&title=Om Sai Nursing Home,&dis=GAYA', last_updated=datetime.datetime(2021, 5, 2, 22, 40), resources=[Resource(resource_type='TOTAL_BEDS', resource_description='hospital beds', resource_total='10', resource_available='10'), Resource(resource_type='ICU_WITHOUT_VENTILATOR', resource_description='icu beds', resource_total='0', resource_available='0')])
# Hospital(name='Sri Krishna Hospital', address='', district='GAYA', city='', state='BIHAR', location='/DailyDashboard/Map?lat=0&lon=0&title=Sri Krishna Hospital,&dis=GAYA', last_updated=datetime.datetime(2021, 5, 2, 22, 41), resources=[Resource(resource_type='TOTAL_BEDS', resource_description='hospital beds', resource_total='6', resource_available='6'), Resource(resource_type='ICU_WITHOUT_VENTILATOR', resource_description='icu beds', resource_total='0', resource_available='0')])
# Hospital(name='Harihar Global Institute & Research center', address='', district='GAYA', city='', state='BIHAR', location='/DailyDashboard/Map?lat=0&lon=0&title=Harihar Global Institute & Research center,&dis=GAYA', last_updated=datetime.datetime(2021, 5, 2, 22, 43), resources=[Resource(resource_type='TOTAL_BEDS', resource_description='hospital beds', resource_total='6', resource_available='6'), Resource(resource_type='ICU_WITHOUT_VENTILATOR', resource_description='icu beds', resource_total='0', resource_available='0')])
# Hospital(name='Prakash Multispeciality Hospital', address='', district='GAYA', city='', state='BIHAR', location='/DailyDashboard/Map?lat=0&lon=0&title=Prakash Multispeciality Hospital,&dis=GAYA', last_updated=datetime.datetime(2021, 5, 2, 22, 46), resources=[Resource(resource_type='TOTAL_BEDS', resource_description='hospital beds', resource_total='7', resource_available='7'), Resource(resource_type='ICU_WITHOUT_VENTILATOR', resource_description='icu beds', resource_total='0', resource_available='0')])
# Hospital(name='JP Memorial Institute & Reseach center', address='', district='GAYA', city='', state='BIHAR', location='/DailyDashboard/Map?lat=0&lon=0&title=JP Memorial Institute & Reseach center,&dis=GAYA', last_updated=datetime.datetime(2021, 5, 2, 22, 47), resources=[Resource(resource_type='TOTAL_BEDS', resource_description='hospital beds', resource_total='6', resource_available='6'), Resource(resource_type='ICU_WITHOUT_VENTILATOR', resource_description='icu beds', resource_total='0', resource_available='0')])
