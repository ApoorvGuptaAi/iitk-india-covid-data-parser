# %%
import requests
import os

# %%
URL = "http://{}/dataLeads?state={}".format(os.environ.get('INDIA_COVID_HOST'), "Delhi")

# %%
data = requests.get(URL).json()
data
# Out:
# {'dataLeads': [{'_id': '60928a8337587e8cb7778907',
#    'status': 'UNVERIFIED',
#    'resources': [{'_id': '60928a8337587e8cb7778908',
#      'resourceType': 'BEDS',
#      'quantity': 0}],
#    'lastUpdatedAt': '2021-05-05T05:34:00.000Z',
#    'vendor': {'_id': '60909c93fb4da74a46ca5322',
#     'name': 'Jeewan Nursing Home, Gate No. 2',
#     'uniqueId': 'Delhi-Delhi-Delhi-Jeewan Nursing Home, Gate No. 2',
#     'createdAt': '2021-05-04T01:00:03.797Z',
#     'address': {'completeAddress': 'Jeewan Nagar, Near Ashram New Delhi:110014',
#      'city': 'Delhi',
#      'district': 'Delhi',
#      'state': 'Delhi'}},
#    'createdAt': '2021-05-05T12:07:31.133Z'},
#   {'_id': '6093816d88b1899623006b50',
#    'status': 'UNVERIFIED',
#    'resources': [{'_id': '6093816d88b1899623006b53',
#      'resourceType': 'BED_WITHOUT_OXYGEN',
#      'quantity': 1786,
#      'totalQuantity': 21851,
#      'description': 'beds'},
#     {'_id': '6093816d88b1899623006b52',
# ...

# %%
times = [entry["createdAt"] for entry in data["dataLeads"]]
times
# Out:
# ['2021-05-05T12:07:31.133Z',
#  '2021-05-06T05:41:01.245Z',
#  '2021-05-06T06:07:28.507Z',
#  '2021-05-06T06:07:28.528Z',
#  '2021-05-06T06:07:28.566Z',
#  '2021-05-06T06:07:28.585Z',
#  '2021-05-06T06:07:28.624Z',
#  '2021-05-06T06:07:28.645Z',
#  '2021-05-06T06:07:28.685Z',
#  '2021-05-06T06:07:28.725Z',
#  '2021-05-06T06:07:28.762Z',
#  '2021-05-06T06:07:28.784Z',
#  '2021-05-06T06:07:28.838Z',
#  '2021-05-06T06:07:28.876Z',
#  '2021-05-06T06:07:28.904Z',
#  '2021-05-06T06:07:28.943Z',
#  '2021-05-06T06:07:28.965Z',
#  '2021-05-06T06:07:29.023Z',
#  '2021-05-06T06:07:29.048Z',
#  '2021-05-06T06:07:29.084Z',
#  '2021-05-06T06:07:29.105Z',
#  '2021-05-06T06:07:29.154Z',
#  '2021-05-06T06:07:29.174Z',
#  '2021-05-06T06:07:29.204Z',
#  '2021-05-06T06:07:29.244Z',
#  '2021-05-06T06:07:29.264Z',
#  '2021-05-06T06:07:29.305Z',
#  '2021-05-06T06:07:29.345Z',
#  '2021-05-06T06:07:29.364Z',
#  '2021-05-06T06:07:29.405Z',
#  '2021-05-06T06:07:29.445Z',
#  '2021-05-06T06:07:29.464Z',
# ...

# %%
len(times)
# Out:
# 376
